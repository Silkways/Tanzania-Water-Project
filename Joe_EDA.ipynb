# %% [markdown]
# # Definitions

# %% [markdown]
# amount_tsh - Total static head (amount water available to waterpoint)
#
# date_recorded - The date the row was entered
#
# funder - Who funded the well
#
# gps_height - Altitude of the well
#
# installer - Organization that installed the well
#
# longitude - GPS coordinate
#
# latitude - GPS coordinate
#
# wpt_name - Name of the waterpoint if there is one
#
# num_private -
#
# basin - Geographic water basin
#
# subvillage - Geographic location
#
# region - Geographic location
#
# region_code - Geographic location (coded)
#
# district_code - Geographic location (coded)
#
# lga - Geographic location
#
# ward - Geographic location
#
# population - Population around the well
#
# public_meeting - True/False
#
# recorded_by - Group entering this row of data
#
# scheme_management - Who operates the waterpoint
#
# scheme_name - Who operates the waterpoint
#
# permit - If the waterpoint is permitted
#
# construction_year - Year the waterpoint was constructed
#
# extraction_type - The kind of extraction the waterpoint uses
#
# extraction_type_group - The kind of extraction the waterpoint uses
#
# extraction_type_class - The kind of extraction the waterpoint uses
#
# management - How the waterpoint is managed
#
# management_group - How the waterpoint is managed
#
# payment - What the water costs
#
# payment_type - What the water costs
#
# water_quality - The quality of the water
#
# quality_group - The quality of the water
#
# quantity - The quantity of water
#
# quantity_group - The quantity of water
#
# source - The source of the water
#
# source_type - The source of the water
#
# source_class - The source of the water
#
# waterpoint_type - The kind of waterpoint
#
# waterpoint_type_group - The kind of waterpoint

# %% [markdown]
# # Package Installation

# %%
import pandas as pd
import pandas as np
import geopandas as geo
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score
from sklearn.tree import export_graphviz
from IPython.display import Image  
from pydotplus import graph_from_dot_data
from IPython.display import display
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# The labels in this dataset are simple. There are three possible values:
# functional - the waterpoint is operational and there are no repairs needed
# functional needs repair - the waterpoint is operational, but needs repairs
# non functional - the waterpoint is not operational

# %% [markdown]
# # Dataset

# %%
X = pd.read_csv('Data/X.csv')
y = pd.read_csv('Data/Y.csv')
X1 = pd.read_csv('Data/X1.csv')

df = pd.merge(y,X,on='id')

# %%
X.columns
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group', 'extraction_type_class',
#        'management', 'management_group', 'payment', 'payment_type',
#        'water_quality', 'quality_group', 'quantity', 'quantity_group',
#        'source', 'source_type', 'source_class', 'waterpoint_type',
#        'waterpoint_type_group'],
#       dtype='object')

# %%
import geopandas as gpd
import descartes
from shapely.geometry import Point,Polygon
import matplotlib.pyplot as plt

map_tz = gpd.read_file('waterways/waterways.shp')


crs = {'init' : 'espg:4326'}
map_tz
# Out:
#          osm_id         name    type width  \
# 0      23334736         None   river  None
# 1      23334747         None   river  None
# 2      23334772         None   river  None
# 3      23334775         None   river  None
# 4      23334784         None   canal  None
# ...         ...          ...     ...   ...
# 2830  300922890         None  stream  None
# 2831  300922891         None  stream  None
# 2832  300922892         None  stream  None
# 2833  300922914  Themi River   river  None
# 2834  301080211      Ruchugi   river  None
#
#                                                geometry
# 0     LINESTRING (39.26245 -6.81581, 39.26223 -6.816...
# 1     LINESTRING (39.26245 -6.81581, 39.26219 -6.815...
# 2     LINESTRING (39.23955 -6.82363, 39.23936 -6.823...
# 3     LINESTRING (39.23955 -6.82363, 39.23952 -6.823...
# 4     LINESTRING (39.26848 -6.81696, 39.26873 -6.817...
# ...                                                 ...
# 2830  LINESTRING (36.65861 -3.44880, 36.65863 -3.448...
# 2831  LINESTRING (36.64600 -3.46509, 36.64598 -3.465...
# 2832  LINESTRING (36.66111 -3.45013, 36.66107 -3.450...
# 2833  LINESTRING (36.70302 -3.44895, 36.70309 -3.449...
# 2834  LINESTRING (30.34240 -4.75282, 30.34226 -4.752...
#
# [2835 rows x 5 columns]

# %%
well_points = X[['longitude', 'latitude']].apply(lambda row:
              Point(row["longitude"], row["latitude"]), axis=1)
geo_wells = gpd.GeoDataFrame({"geometry": well_points})

# %%
geo_wells
# Out:
#                          geometry
# 0       POINT (34.93809 -9.85632)
# 1       POINT (34.69877 -2.14747)
# 2       POINT (37.46066 -3.82133)
# 3      POINT (38.48616 -11.15530)
# 4       POINT (31.13085 -1.82536)
# ...                           ...
# 59395   POINT (37.16981 -3.25385)
# 59396   POINT (35.24999 -9.07063)
# 59397   POINT (34.01709 -8.75043)
# 59398   POINT (35.86132 -6.37857)
# 59399   POINT (38.10405 -6.74746)
#
# [59400 rows x 1 columns]

# %%
map_tz.crs = {'init': 'epsg:4326'}
geo_wells.crs = {'init': 'epsg:4326'}

# %%
fig, ax = plt.subplots(1, figsize=(30,30))
base = map_tz.plot(ax=ax, color='gray')
geo_wells.plot(ax=base, marker="o",color='blue',  markersize=0.5, alpha=0.5)
plt.xlim(28,43)
# _ = ax.axis('off')
ax.set_title("Wells")
# Out:
# Text(0.5, 1, 'Wells')

# %%
map_water = gpd.read_file('Waterbodies/Waterbodies.shp')
map_water.crs = {'init': 'epsg:4326'}

# %%
fig, ax = plt.subplots(1, figsize=(30,30))
base = map_water.plot(ax=ax, color='blue')
geo_wells.plot(ax=base, marker="o",color='red',  markersize=0.5, alpha=0.5)
plt.xlim(28,43)
ax.set_facecolor('xkcd:forest green')
# _ = ax.axis('off')
ax.set_title("Wells")
# Out:
# Text(0.5, 1, 'Wells')

# %%
df.head()
# Out:
#       id    status_group  amount_tsh date_recorded        funder  gps_height  \
# 0  69572      functional      6000.0    2011-03-14         Roman        1390
# 1   8776      functional         0.0    2013-03-06       Grumeti        1399
# 2  34310      functional        25.0    2013-02-25  Lottery Club         686
# 3  67743  non functional         0.0    2013-01-28        Unicef         263
# 4  19728      functional         0.0    2011-07-13   Action In A           0
#
#       installer  longitude   latitude              wpt_name  ...  \
# 0         Roman  34.938093  -9.856322                  none  ...
# 1       GRUMETI  34.698766  -2.147466              Zahanati  ...
# 2  World vision  37.460664  -3.821329           Kwa Mahundi  ...
# 3        UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu  ...
# 4       Artisan  31.130847  -1.825359               Shuleni  ...
#
#    payment_type water_quality quality_group      quantity  quantity_group  \
# 0      annually          soft          good        enough          enough
# 1     never pay          soft          good  insufficient    insufficient
# 2    per bucket          soft          good        enough          enough
# 3     never pay          soft          good           dry             dry
# 4     never pay          soft          good      seasonal        seasonal
#
#                  source           source_type source_class  \
# 0                spring                spring  groundwater
# 1  rainwater harvesting  rainwater harvesting      surface
# 2                   dam                   dam      surface
# 3           machine dbh              borehole  groundwater
# 4  rainwater harvesting  rainwater harvesting      surface
#
#                waterpoint_type waterpoint_type_group
# 0           communal standpipe    communal standpipe
# 1           communal standpipe    communal standpipe
# 2  communal standpipe multiple    communal standpipe
# 3  communal standpipe multiple    communal standpipe
# 4           communal standpipe    communal standpipe
#
# [5 rows x 41 columns]

# %%
gdf = gpd.GeoDataFrame(pd.concat([map_tz,map_water]))

gdf.crs = {'init': 'epsg:4326'}

# %%
fig, ax = plt.subplots(1, figsize=(30,30))
base = gdf.plot(ax=ax)
geo_wells.plot(ax=base, marker="o",color='red',  markersize=0.5, alpha=0.5)
plt.xlim(28,43)
# _ = ax.axis('off')
ax.set_title("Wells")
# Out:
# Text(0.5, 1, 'Wells')

# %%
non_func = df[df['status_group'] == 'non functional']
non_func['funder'].value_counts()
# Out:
# Government Of Tanzania    4663
# Danida                    1242
# Hesawa                    1034
# World Bank                 707
# Kkkt                       498
#                           ...
# Ggm                          1
# Vicfish                      1
# Mtambo                       1
# Africa Amini Alama           1
# Jeshi Lawokovu               1
# Name: funder, Length: 1019, dtype: int64

# %%
df['funder'].value_counts()
# Out:
# Government Of Tanzania    9084
# Danida                    3114
# Hesawa                    2202
# Rwssp                     1374
# World Bank                1349
#                           ...
# Iucn                         1
# Louise Elucas Sala           1
# Tareto                       1
# Majengo Prima                1
# Idf                          1
# Name: funder, Length: 1897, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                           0
# status_group                 0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# dtype: int64

# %%
df['installer'].fillna('other', inplace = True)
df['funder'].fillna('other', inplace = True)
df['public_meeting'].fillna('False', inplace = True)
df['scheme_management'].fillna('other',inplace = True)
df['permit'].fillna('False', inplace = True)
df['scheme_name'].fillna('other', inplace = True)
df.dropna(subset=['subvillage'],inplace = True)
df.drop(columns =['recorded_by','construction_year'], inplace = True)

# %%
df.isnull().sum()
# Out:
# id                       0
# status_group             0
# amount_tsh               0
# date_recorded            0
# funder                   0
# gps_height               0
# installer                0
# longitude                0
# latitude                 0
# wpt_name                 0
# num_private              0
# basin                    0
# subvillage               0
# region                   0
# region_code              0
# district_code            0
# lga                      0
# ward                     0
# population               0
# public_meeting           0
# scheme_management        0
# scheme_name              0
# permit                   0
# extraction_type          0
# extraction_type_group    0
# extraction_type_class    0
# management               0
# management_group         0
# payment                  0
# payment_type             0
# water_quality            0
# quality_group            0
# quantity                 0
# quantity_group           0
# source                   0
# source_type              0
# source_class             0
# waterpoint_type          0
# waterpoint_type_group    0
# dtype: int64

# %%
df.sample(n=20)
# Out:
#           id             status_group  amount_tsh date_recorded  \
# 32925  48272               functional         0.0    2013-02-02
# 24116  34077           non functional         0.0    2011-07-30
# 53941    765               functional         0.0    2011-04-09
# 54920  36643           non functional         0.0    2011-07-10
# 8859   59435           non functional       600.0    2012-10-23
# 15369  22311               functional        30.0    2013-03-16
# 28713  41305               functional         0.0    2013-01-16
# 57510  67222           non functional       500.0    2013-03-25
# 36010   9496           non functional         0.0    2011-08-27
# 50241  44483           non functional         0.0    2011-03-12
# 50121  51309           non functional         0.0    2012-11-13
# 17572  11067           non functional         0.0    2011-04-04
# 19528  31695  functional needs repair       200.0    2011-04-18
# 15985  45232  functional needs repair         0.0    2011-03-30
# 13359  18519               functional        30.0    2011-03-12
# 41003  71391           non functional         0.0    2013-03-16
# 34546  12764               functional        25.0    2011-08-03
# 5324   15431               functional         0.0    2011-07-10
# 44532   4492               functional         0.0    2011-04-08
# 39581  48952               functional      3600.0    2013-01-29
#
#                        funder  gps_height    installer  longitude  \
# 32925            World Vision           0  ADP Busangi  32.544656
# 24116                    Elct           0         KKKT   0.000000
# 53941                   other           0        other  34.133583
# 54920  Government Of Tanzania           0          DWE  31.447877
# 8859       Kanisa La Menonite        1209          MTN  34.093716
# 15369  Government Of Tanzania         982          DWE  36.820457
# 28713                   other        1589        other  35.039968
# 57510  Government Of Tanzania        1838          DWE  36.625732
# 36010                   Ridep           0          DWE  33.618290
# 50241  Government Of Tanzania           0        GOVER  35.487350
# 50121  Government Of Tanzania           0   Government  34.092423
# 17572                   Water           0        Commu  36.002007
# 19528                    Cefa        1576         CEFA  35.173885
# 15985                   other           0        other  34.793685
# 13359                     Wua         179           WU  38.354662
# 41003                   other         963        other  35.888438
# 34546  Government Of Tanzania          60          DWE  39.041541
# 5324                   Hesawa           0          DWE  31.127296
# 44532                   other           0        other  33.868576
# 39581  Government Of Tanzania         899          DWE  29.820545
#
#            latitude                    wpt_name  ...  payment_type  \
# 32925 -3.626691e+00                       Mhida  ...       unknown
# 24116 -2.000000e-08                     Bombani  ...     never pay
# 53941 -8.811686e+00                 Kwa Mwijuma  ...       monthly
# 54920 -1.458006e+00                 Kwa Taasare  ...     never pay
# 8859  -1.118879e+00             Kwa Okechi Seol  ...       monthly
# 15369 -3.485044e+00                  Kwa Godwin  ...    per bucket
# 28713 -4.606017e+00           Murigha Girls Sec  ...     never pay
# 57510 -3.217610e+00                    Olubomba  ...    on failure
# 36010 -2.740634e+00                   Kwasabuni  ...     never pay
# 50241 -6.654411e+00                   Mwl. Tupa  ...       unknown
# 50121 -3.416669e+00            Khadija Mashauri  ...         other
# 17572 -6.218030e+00                     Shuleni  ...    per bucket
# 19528 -9.261494e+00          Kwa Laurent Kadege  ...       monthly
# 15985 -8.208926e+00             Shule Ya Msingi  ...     never pay
# 13359 -6.638822e+00                Mzee Mwalami  ...    per bucket
# 41003 -3.377452e+00  Kigongoni Primary School 2  ...     never pay
# 34546 -5.034966e+00               Kwa Augustino  ...    per bucket
# 5324  -1.697637e+00                    Ubasingo  ...      annually
# 44532 -9.372983e+00                     Kandete  ...     never pay
# 39581 -4.882503e+00            Kwa Danil Hebeye  ...      annually
#
#       water_quality quality_group      quantity  quantity_group  \
# 32925         milky         milky        enough          enough
# 24116       unknown       unknown           dry             dry
# 53941          soft          good      seasonal        seasonal
# 54920       unknown       unknown           dry             dry
# 8859           soft          good        enough          enough
# 15369          soft          good  insufficient    insufficient
# 28713          soft          good  insufficient    insufficient
# 57510          soft          good  insufficient    insufficient
# 36010          soft          good  insufficient    insufficient
# 50241          soft          good           dry             dry
# 50121          soft          good        enough          enough
# 17572          soft          good           dry             dry
# 19528          soft          good        enough          enough
# 15985          soft          good      seasonal        seasonal
# 13359          soft          good        enough          enough
# 41003          soft          good  insufficient    insufficient
# 34546          soft          good        enough          enough
# 5324           soft          good        enough          enough
# 44532          soft          good        enough          enough
# 39581          soft          good        enough          enough
#
#                      source           source_type source_class  \
# 32925          shallow well          shallow well  groundwater
# 24116          shallow well          shallow well  groundwater
# 53941                 river            river/lake      surface
# 54920          shallow well          shallow well  groundwater
# 8859                   lake            river/lake      surface
# 15369                spring                spring  groundwater
# 28713  rainwater harvesting  rainwater harvesting      surface
# 57510                spring                spring  groundwater
# 36010          shallow well          shallow well  groundwater
# 50241           machine dbh              borehole  groundwater
# 50121                 river            river/lake      surface
# 17572           machine dbh              borehole  groundwater
# 19528                 river            river/lake      surface
# 15985                 river            river/lake      surface
# 13359                 river            river/lake      surface
# 41003                spring                spring  groundwater
# 34546                 river            river/lake      surface
# 5324                 spring                spring  groundwater
# 44532                spring                spring  groundwater
# 39581                 river            river/lake      surface
#
#                    waterpoint_type waterpoint_type_group
# 32925                    hand pump             hand pump
# 24116                    hand pump             hand pump
# 53941           communal standpipe    communal standpipe
# 54920                    hand pump             hand pump
# 8859   communal standpipe multiple    communal standpipe
# 15369           communal standpipe    communal standpipe
# 28713           communal standpipe    communal standpipe
# 57510           communal standpipe    communal standpipe
# 36010                    hand pump             hand pump
# 50241  communal standpipe multiple    communal standpipe
# 50121  communal standpipe multiple    communal standpipe
# 17572           communal standpipe    communal standpipe
# 19528           communal standpipe    communal standpipe
# 15985           communal standpipe    communal standpipe
# 13359           communal standpipe    communal standpipe
# 41003           communal standpipe    communal standpipe
# 34546           communal standpipe    communal standpipe
# 5324            communal standpipe    communal standpipe
# 44532           communal standpipe    communal standpipe
# 39581  communal standpipe multiple    communal standpipe
#
# [20 rows x 39 columns]

# %%
df.district_code.value_counts()
# Out:
# 1     12193
# 2     11173
# 3      9637
# 4      8999
# 5      4356
# 6      4074
# 7      3343
# 8      1043
# 30      995
# 33      874
# 53      745
# 43      505
# 13      391
# 23      293
# 63      195
# 62      109
# 60       63
# 0        23
# 80       12
# 67        6
# Name: district_code, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59029 entries, 0 to 59399
# Data columns (total 39 columns):
# id                       59029 non-null int64
# status_group             59029 non-null object
# amount_tsh               59029 non-null float64
# date_recorded            59029 non-null object
# funder                   59029 non-null object
# gps_height               59029 non-null int64
# installer                59029 non-null object
# longitude                59029 non-null float64
# latitude                 59029 non-null float64
# wpt_name                 59029 non-null object
# num_private              59029 non-null int64
# basin                    59029 non-null object
# subvillage               59029 non-null object
# region                   59029 non-null object
# region_code              59029 non-null int64
# district_code            59029 non-null int64
# lga                      59029 non-null object
# ward                     59029 non-null object
# population               59029 non-null int64
# public_meeting           59029 non-null object
# scheme_management        59029 non-null object
# scheme_name              59029 non-null object
# permit                   59029 non-null object
# extraction_type          59029 non-null object
# extraction_type_group    59029 non-null object
# extraction_type_class    59029 non-null object
# management               59029 non-null object
# management_group         59029 non-null object
# payment                  59029 non-null object
# payment_type             59029 non-null object
# water_quality            59029 non-null object
# quality_group            59029 non-null object
# quantity                 59029 non-null object
# quantity_group           59029 non-null object
# source                   59029 non-null object
# source_type              59029 non-null object
# source_class             59029 non-null object
# waterpoint_type          59029 non-null object
# waterpoint_type_group    59029 non-null object
# dtypes: float64(3), int64(6), object(30)
# memory usage: 18.0+ MB

# %% [markdown]
# # Initial split of DataSet (Train / Test set)

# %%
y = df['status_group']
X = df.loc[:, ['installer', 'payment_type', 'water_quality', 'source_class', 'waterpoint_type']] # Confirm the number of independent variables
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, train_size=0.67)

# %% [markdown]
# # Baseline Model - Decision Tree

# %%
X_ohe = pd.get_dummies(X_train, prefix = ['installer','payment_type', 'water_quality',  'source_class','waterpoint_type'])
y_ohe = pd.get_dummies(y_train, prefix = ['status_group'])

# %%
clf = DecisionTreeClassifier(criterion='entropy', max_depth = 100, min_samples_leaf = 500)
clf.fit(X_ohe, y_ohe)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=100, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=500, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# y_preds = clf.predict(X_ohe)
# print('Accuracy: ', accuracy_score(y_ohe, y_preds))

# %%
# clf = DecisionTreeClassifier(criterion='entropy', max_depth = 5, min_samples_leaf = 200)
# clf.fit(X_ohe, y_ohe) #encoded categorical variable using pd.get_dummies()

# from sklearn.tree import export_graphviz
# # Export as dot file
# export_graphviz(clf, out_file='tree.dot', 
#                 feature_names = X_ohe.columns,
#                 class_names = np.unique(y).astype(str),
#                 rounded = True, proportion = False, 
#                 precision = 2, filled = True)

# # Convert to png 
# from subprocess import call
# call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])

# # Display in jupyter notebook
# from IPython.display import Image
# Image(filename = 'tree.png')

# %%
# clf1 = DecisionTreeClassifier()
# param_grid = {'criterion':['gini','entropy'], 'max_depth': [5,10,15,20,50], 'min_samples_leaf':[100, 200, 300, 400]}
# gs = GridSearchCV(clf1, param_grid, cv = 5)

# gs.fit(X_ohe, y_ohe)
# gs.best_params_
